# %%
# %pip install openai yt-dlp ffmpeg --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 11.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 16.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 11.0.3
#     Uninstalling websockets-11.0.3:
#       Successfully uninstalled websockets-11.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# realtime 1.0.0 requires websockets<11.0,>=10.3, but you have websockets 12.0 which is incompatible.
# pyppeteer 1.0.2 requires pyee<9.0.0,>=8.1.0, but you have pyee 9.0.4 which is incompatible.
# pyppeteer 1.0.2 requires urllib3<2.0.0,>=1.25.8, but you have urllib3 2.0.7 which is incompatible.
# ...

# %%
# !yt-dlp https://youtu.be/2TF3HFMDSF4
# Out:
# [youtube] Extracting URL: https://youtu.be/2TF3HFMDSF4
# [youtube] 2TF3HFMDSF4: Downloading webpage
# [youtube] 2TF3HFMDSF4: Downloading ios player API JSON
# [youtube] 2TF3HFMDSF4: Downloading android player API JSON
# [youtube] 2TF3HFMDSF4: Downloading m3u8 information
# [info] 2TF3HFMDSF4: Downloading 1 format(s): 136+251
# [download] Destination: We need a new logo – Stable Diffusion [2TF3HFMDSF4].f136.mp4
# [download] 100% of   34.40MiB in 00:00:05 at 6.18MiB/s0;33m00:000m
# [download] Destination: We need a new logo – Stable Diffusion [2TF3HFMDSF4].f251.webm
# [download] 100% of    9.81MiB in 00:00:09 at 1.04MiB/s0;33m00:00
# [Merger] Merging formats into "We need a new logo – Stable Diffusion [2TF3HFMDSF4].mkv"
# Deleting original file We need a new logo – Stable Diffusion [2TF3HFMDSF4].f251.webm (pass -k to keep)
# Deleting original file We need a new logo – Stable Diffusion [2TF3HFMDSF4].f136.mp4 (pass -k to keep)

# %% [markdown]
# Visit your OpenAI account to get an API Key -> https://platform.openai.com/account/api-keys

# %%
# Get the openai secret key
import getpass
from openai import OpenAI

secret_key = getpass.getpass('Please enter your openai key: ')
client = OpenAI()
client.api_key = secret_key

# %%
# !ffmpeg -i "We need a new logo – Stable Diffusion [2TF3HFMDSF4].mkv" -vn -ab 128k output.mp3
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
# ...

# %%
audio_file = open("output.mp3", "rb")
transcript = client.audio.transcriptions.create(model="whisper-1", file=audio_file, response_format="verbose_json")
print(transcript)
# Out:
# Transcription(text="I'm going to walk you through how to create a company logo with Stable Diffusion for free in your Google Colab notebook. So this is the Stable Diffusion Google Colab. They set this up so you can run this in the Google environment. You don't need to download anything onto your computer. So it's much easier to run and it also gives you a free GPU, which is like a specialized computer that's very good at running this type of thing quickly. So I'm just going to click create a copy to drive and then that's going to create a copy. It's just creating a copy right now. It might take a couple of minutes. Okay a copy is created and we're basically just going to go through this setup process here. Now we have this copy, we can call it whatever I want. It's this is ours now and we can just run this. It says it requires higher RAM. Don't worry about that. Okay, I'm just going to get rid of any other sessions, whatever. So hopefully this will run now to connect. So that is conn
# ...

# %%
transcript.segments
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 5.559999942779541,
#   'text': " I'm going to walk you through how to create a company logo with Stable Diffusion for free",
#   'tokens': [50364,
#    286,
#    478,
#    516,
#    281,
#    1792,
#    291,
#    807,
#    577,
#    281,
#    1884,
#    257,
#    2237,
#    9699,
#    365,
#    745,
#    712,
#    413,
#    3661,
#    5704,
#    337,
#    1737,
#    50642],
#   'temperature': 0.0,
#   'avg_logprob': -0.2637440860271454,
#   'compression_ratio': 1.6296296119689941,
#   'no_speech_prob': 0.34775829315185547},
#  {'id': 1,
#   'seek': 0,
#   'start': 5.559999942779541,
#   'end': 8.5600004196167,
#   'text': ' in your Google Colab notebook.',
#   'tokens': [50642, 294, 428, 3329, 4004, 455, 21060, 13, 50792],
#   'temperature': 0.0,
#   'avg_logprob': -0.2637440860271454,
#   'compression_ratio': 1.6296296119689941,
#   'no_speech_prob': 0.34775829315185547},
#  {'id': 2,
#   'seek': 0,
# ...

# %%
for segment in transcript.segments:
    start_minutes, start_seconds = divmod(segment["start"], 60)
    timestamp = f"{round(start_minutes):02d}:{round(start_seconds):02d}"
    text = segment["text"]
    print(f"{timestamp} - {text}")
# Out:
# 00:00 -  I'm going to walk you through how to create a company logo with Stable Diffusion for free
# 00:06 -  in your Google Colab notebook.
# 00:09 -  So this is the Stable Diffusion Google Colab.
# 00:14 -  They set this up so you can run this in the Google environment.
# 00:17 -  You don't need to download anything onto your computer.
# 00:20 -  So it's much easier to run and it also gives you a free GPU, which is like a specialized
# 00:25 -  computer that's very good at running this type of thing quickly.
# 00:29 -  So I'm just going to click create a copy to drive and then that's going to create a
# 00:38 -  copy.
# 00:39 -  It's just creating a copy right now.
# 00:40 -  It might take a couple of minutes.
# 00:50 -  Okay a copy is created and we're basically just going to go through this setup process
# 00:55 -  here.
# 00:56 -  Now we have this copy, we can call it whatever I want.
# 00:59 -  It's this is ours now and we can just run this.
# ...
