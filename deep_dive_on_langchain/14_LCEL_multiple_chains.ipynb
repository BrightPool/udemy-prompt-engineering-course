# %% [markdown]
# # LangChain Expression Language

# %%
# %pip install -q langchain-openai langchain-core

# %%
import os
from getpass import getpass

# API Key Setup - uses environment variable or prompts for input
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %%
from operator import itemgetter
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %% [markdown]
# --------------------------
#
# ## Multiple LLM Chains

# %%
prompt1 = ChatPromptTemplate.from_template("what is the city {person} is from?")
prompt2 = ChatPromptTemplate.from_template(
    "what country is the city {city} in? respond in {language}"
)

model = ChatOpenAI()

chain1 = prompt1 | model | StrOutputParser()

chain2 = (
    {"city": chain1, "language": itemgetter("language")}
    | prompt2
    | model
    | StrOutputParser()
)

chain2.invoke({"person": "obama", "language": "spanish"})
# Out:
# 'El país donde nació el 44º presidente de los Estados Unidos, Barack Obama, es Estados Unidos. Nació en Honolulu, Hawái.'

# %% [markdown]
# ## Summary
#
# - **Multiple chains can be composed** by using the output of one chain as input to another, allowing you to break complex tasks into smaller, manageable steps.
# - Use **itemgetter** to pass through values from the original input alongside the output of intermediate chains, enabling data to flow across multiple chain steps.
# - This pattern is useful for **multi-step reasoning tasks** where you need to first extract information (e.g., a city name) and then use it in a follow-up query (e.g., finding the country).
