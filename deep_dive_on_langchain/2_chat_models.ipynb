# %% [markdown]
# ## Chat Models

# %%
# %pip install -q langchain-openai langchain-core

# %%
import os
from getpass import getpass

# API Key Setup - uses environment variable or prompts for input
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# %%
from langchain_openai import ChatOpenAI

# chat = ChatOpenAI(openai_api_key="...")

# If you have an envionrment variable set for OPENAI_API_KEY, you can just do:
chat = ChatOpenAI()

# %%
chat.invoke("Hello, how are you?")
# Out:
# AIMessage(content="Hello! I'm an AI, so I don't have feelings, but I'm here to assist you. How can I help you today?")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

text = "What would be a good company name for a company that makes colorful socks?"
messages = [HumanMessage(content=text)]
result = chat.invoke(messages)

# %%
print(result.content)
# Out:
# Colorful Step Co.

# %% [markdown]
# ---
#
# ## Inserting the SystemMessage instead of a HumanMessage

# %%
text = "What would be a good company name for a company that makes colorful socks?"

messages = [SystemMessage(content=text)]
chat(messages)
# Out:
# AIMessage(content='Socktastic')

# %% [markdown]
# ## Summary
#
# - **ChatOpenAI** is the primary LangChain wrapper for OpenAI's chat models, which can be initialized with an API key or automatically read from the `OPENAI_API_KEY` environment variable.
# - You can invoke the model with a simple string or structured messages using **HumanMessage** and **SystemMessage** classes to control the conversation flow.
# - The choice between `HumanMessage` and `SystemMessage` affects how the model interprets the input, with system messages typically used for setting behavior and human messages for user queries.
