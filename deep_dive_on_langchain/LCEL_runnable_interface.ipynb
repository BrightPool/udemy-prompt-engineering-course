# %% [markdown]
# # LangChain Expression Language

# %%
# %pip install langchain langchain-openai langchain-community langchain-text-splitters --upgrade
# Out:
# Requirement already satisfied: langchain==0.2.17 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (0.2.17)
# Requirement already satisfied: langchain-openai==0.1.25 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (0.1.25)
# Requirement already satisfied: langchain-community==0.2.17 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (0.2.17)
# Requirement already satisfied: langchain-text-splitters==0.2.4 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (0.2.4)
# Requirement already satisfied: langsmith==0.1.147 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (0.1.147)
# Requirement already satisfied: PyYAML>=5.3 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain==0.2.17) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain==0.2.17) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain==0.2.17) (3.13.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.43 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain==0.2.17) (0.2.43)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain==0.2.17) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain==0.2.17) (2.12.5)
# Requirement already satisfied: requests<3,>=2 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain==0.2.17) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain==0.2.17) (8.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langsmith==0.1.147) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langsmith==0.1.147) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langsmith==0.1.147) (1.0.0)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-openai==0.1.25) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-openai==0.1.25) (0.12.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-community==0.2.17) (0.6.7)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.17) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.17) (0.9.0)
# Requirement already satisfied: anyio in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith==0.1.147) (4.12.1)
# Requirement already satisfied: certifi in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith==0.1.147) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith==0.1.147) (1.0.9)
# Requirement already satisfied: idna in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith==0.1.147) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith==0.1.147) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain==0.2.17) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain==0.2.17) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.43->langchain==0.2.17) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain==0.2.17) (3.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.25) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.25) (0.13.0)
# Requirement already satisfied: sniffio in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.25) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.25) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain==0.2.17) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain==0.2.17) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain==0.2.17) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.2.17) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.2.17) (2.6.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.1.25) (2026.2.28)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.17) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
from openai import OpenAI
import os

# Set up your OpenAI client
if not os.getenv("OPENAI_API_KEY"):
    secret_key = getpass.getpass("Enter your OpenAI API key: ")
    os.environ["OPENAI_API_KEY"] = secret_key

# %% [markdown]
# Explain the basic syntax of [LangChain Expression Language](https://python.langchain.com/docs/expression_language/), which uses the pipe symbol `|` to connect components. Each component represents a specific task or action.

# %% [markdown]
# To make it as easy as possible to create custom chains, LangChain implemented a `Runnable` protocol. The Runnable protocol is implemented for most components. This is a standard interface, which makes it easy to define custom chains as well as invoke them in a standard way. The standard interface includes:
#
# - `stream`: stream back chunks of the response
# - `invoke`: call the chain on an input
# - `batch`: call the chain on a list of inputs
#
# These also have corresponding async methods:
#
# - `astream`: stream back chunks of the response async
# - `ainvoke`: call the chain on an input async
# - `abatch`: call the chain on a list of inputs async
# - `astream_log`: stream back intermediate steps as they happen, in addition to the final response
#
# ----

# %% [markdown]
# ## The Runnable Protocol:
#
# A unit of work that can be invoked, batched, streamed, transformed and composed.
#
# All methods accept an optional config argument, which can be used to configure execution, add tags and metadata for tracing and debugging etc.
#
# Runnables expose schematic information about their input, output and config via the input_schema property, the output_schema property and config_schema method.
#
# The LangChain Expression Language (LCEL) is a declarative way to compose Runnables into chains. Any chain constructed this way will automatically have sync, async, batch, and streaming support.
#
# The main composition primitives are `RunnableSequence` and `RunnableParallel`.
#
# ---

# %% [markdown]
# ## RunnableLambda

# %%
from langchain_core.runnables import RunnableLambda

print(type(RunnableLambda(lambda x: x + 1))) # <class 'langchain.schema.runnable.RunnableLambda'>
# Out:
# <class 'langchain_core.runnables.base.RunnableLambda'>

# %%
chain = RunnableLambda(lambda x: x + 1)

# %%
chain.invoke(1)
# Out:
# 2

# %%
chain.invoke(5)
# Out:
# 6

# %% [markdown]
# ## RunnableSequence
#
# `RunnableSequence` invokes a series of runnables sequentially, with one runnable’s output serving as the next’s input. Construct using the `|` operator or by passing a list of runnables to RunnableSequence.

# %%
# A RunnableSequence constructed using the `|` operator
sequence = RunnableLambda(lambda x: x + 1) | (lambda x: x * 2)

print(type(sequence)) # <class 'langchain.schema.runnable.RunnableSequence'>
print('\n\n---')
print(sequence.invoke(1)) # 4
sequence.batch([1, 2, 3]) # [4, 6, 8]
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
#
#
# ---
# 4
# [4, 6, 8]

# %% [markdown]
# ## RunnableParallel
#
# The `RunnableParallel`, allows for multiple runnables to be invoked in parallel, construct using a dictionary of runnables to invoke in parallel.

# %%
# A sequence that contains a RunnableParallel constructed using a dict literal
sequence = RunnableLambda(lambda x: x + 1) | {
    "mul_2": RunnableLambda(lambda x: x * 2),
    "mul_5": RunnableLambda(lambda x: x * 5),
}
sequence.invoke(1)  # {'mul_2': 4, 'mul_5': 10}
# Out:
# {'mul_2': 4, 'mul_5': 10}

# %% [markdown]
# ---------------
#
# ## Combining the output of multiple runnables into a single response
#
# A sequence that contains a RunnableParallel constructed using a dict literal, this is then followed by a RunnableLambda that consumes the output of the RunnableParallel

# %%
sequence = RunnableLambda(lambda x: x + 1) | {
    'mul_2': RunnableLambda(lambda x: x * 2),
    'mul_5': RunnableLambda(lambda x: x * 5)
} | RunnableLambda(lambda x: x['mul_2'] + x['mul_5'])
sequence.invoke(1) # {'mul_2': 4, 'mul_5': 10}
# Out:
# 14

# %%
from langchain_core.runnables import RunnableParallel

parallel = RunnableParallel({
    'mul_2': RunnableLambda(lambda x: x * 2),
    'mul_5': RunnableLambda(lambda x: x * 5)
})

# This is a dictionary, however it will be composed with other runnables when used in a sequence:
parallel_two = {
    'mul_2': RunnableLambda(lambda x: x['input_one'] * 2),
    'mul_5': RunnableLambda(lambda x: x['input_two'] * 5)
}

print(type(parallel)) # <class 'langchain.schema.runnable.RunnableParallel'>
print(type(parallel_two)) # <class 'dict'>
# Out:
# <class 'langchain_core.runnables.base.RunnableParallel'>
# <class 'dict'>

# %%
chain = parallel | RunnableLambda(lambda x: x['mul_2'] + x['mul_5']) 
chain.invoke(5)
# Out:
# 35

# %%
second_chain = parallel_two | RunnableLambda(lambda x: x['mul_2'] + x['mul_5']) 
second_chain.invoke({'input_one': 5, 'input_two': 10})
# Out:
# 60

# %% [markdown]
# ------------------------------------------------
#
# ### You only need a _`Runnable` at the start_, you can use other Python functions _after the first `Runnable`_
#
# Technically you only need a `RunnableLambda` or `RunnableParallel` as the first expression after that you can use Python functions:

# %%
parallel = RunnableParallel({
    'mul_2': RunnableLambda(lambda x: x * 2),
    'mul_5': RunnableLambda(lambda x: x * 5)
})

# This is bad practice:
test = lambda x : x + 1  | parallel
print(test)
try:
    test.invoke(5)
except AttributeError as exc:
    print(exc)
# Out:
# <function <lambda> at 0x10b6b4ae0>
# 'function' object has no attribute 'invoke'

# %%
# This is good practice:
test = RunnableLambda(lambda x: x + 1) | parallel
print(test)
test.invoke(5)
# Out:
# first=RunnableLambda(lambda x: x + 1) middle=[] last={
#   mul_2: RunnableLambda(...),
#   mul_5: RunnableLambda(...)
# }
# {'mul_2': 12, 'mul_5': 30}

# %% [markdown]
# ---
#
# ## Combining Steps in A Runnable

# %%
from langchain_core.runnables import RunnableParallel

parallel = RunnableParallel({
    'item_one': RunnableLambda(lambda x: f"Hello {x['name']} "),
    'item_two': RunnableLambda(lambda x: 'Welcome to the World!')
})

# %%
def combine(x):
    return x['item_one'] + x['item_two']

# %%
parallel_chain_example = parallel | combine
parallel_chain_example.invoke({'name': "James"})
# Out:
# 'Hello James Welcome to the World!'

# %%
lambda_example = RunnableLambda(lambda x: {'item_one': 'Hello ', 'item_two': 'World'})
lambda_chain_example = lambda_example | combine
lambda_chain_example.invoke({})
# Out:
# 'Hello World'
