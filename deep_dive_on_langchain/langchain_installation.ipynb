# %% [markdown]
# # Installation

# %%
# %pip install langchain langchain_openai langchain-community --upgrade
# Out:
# Requirement already satisfied: langchain in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (1.2.12)
# Requirement already satisfied: langchain_openai in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (1.1.11)
# Requirement already satisfied: langchain-community in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain) (1.2.19)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.17)
# Requirement already satisfied: packaging>=23.2.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain_openai) (2.28.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.13.0)
# Requirement already satisfied: sniffio in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.2.28)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jamesaphoenix/Desktop/projects/brightpool/udemy-prompt-engineering-course/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['OPENAI_API_KEY'] = 'API_KEY_HERE'

# %%
# !export OPENAI_API_KEY="..."

# %%
from langchain_openai.chat_models import ChatOpenAI

# chat = ChatOpenAI(openai_api_key="...")

# If you have an envionrment variable set for OPENAI_API_KEY, you can just do:
chat = ChatOpenAI()

# %%
chat.invoke("Hello, how are you?")
# Out:
# AIMessage(content="Hello! I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you with anything you need. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 13, 'total_tokens': 50, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DKOsi5LvIxFFKKHhPqJq404PQ71oE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cfc02-ea82-7801-91b6-d543def86b8a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 37, 'total_tokens': 50, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
